# %%
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Load data

# %%
# def load_proton_a_images(n=10000):
#     return pd.read_pickle('../data/proton_images2a.pkl')[:n]

# def load_particle_data_a(n=10000):
#     return pd.read_pickle('../data/particles_cond_with_mass2a.pkl')[:n]

# def get_proton_images(n=10000):
#     data = load_proton_a_images(n)
#     # preprocess data
#     data = np.log(data+1)
#     return np.float32(data)

# %%
data = pd.read_pickle('../data/data_photonsum_10.pkl')
print('Loaded: ',  data.shape)
data_cond = pd.read_pickle('../data/data_cond_photonsum_10.pkl')
print('Loaded cond: ',  data_cond.shape)
# Out:
# Loaded:  (102262, 56, 30)
# Loaded cond:  (102262, 11)

# %% [markdown]
# ### Preprocess data

# %%
data = np.float32(np.log(data+1))

# %%
# def filter_photon_sum(data_response, data_conditional, min_photon_sum=10):
#     """
#     Returns particle data and responses of experiments with minimum sum of photons.
#     """
#     indecies = data_conditional.index[data_conditional.loc[:, 'PhotonSum'] > min_photon_sum]
#     return data_response[indecies], data_conditional.iloc[indecies].reset_index(drop=True)

# %%
# data, data_cond = filter_photon_sum(data, data_cond, min_photon_sum=20)
# data.shape, data_cond.shape
# Out:
# ((5261, 56, 30), (5261, 11))

# %%
# Credits: majerzemilia

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model, decomposition, manifold, preprocessing
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_curve, roc_curve, auc, accuracy_score, confusion_matrix
from sklearn.model_selection import StratifiedKFold, KFold, train_test_split
from tensorflow.keras import layers
import pickle
import time
from numpy import load
from matplotlib import pyplot
import pickle
import argparse

import tensorflow as tf
from tensorflow import keras
print(tf.__version__)

from tensorflow.compat.v1.keras.layers import Input, Dense, LeakyReLU, Conv2D, MaxPooling2D, UpSampling2D,  Concatenate
from tensorflow.compat.v1.keras.models import Model
from tensorflow.compat.v1.keras.layers import Dense, Reshape, Flatten
from tensorflow.compat.v1.keras.layers import Dropout,BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.losses import mse, binary_crossentropy, logcosh
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend as K

import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

from scipy.stats import wasserstein_distance
import pandas as pd
from utils import sum_channels_parallel_ as sum_channels_parallel
from sklearn.metrics import mean_absolute_error
from datetime import datetime
# Out:
# 2.11.0

# %%
DATE_STR = datetime.now().strftime("%d_%m_%Y_%H_%M")
NAME = "model_"+DATE_STR
print(DATE_STR, NAME)
# Out:
# 24_02_2023_22_41 model_24_02_2023_22_41

# %%
def save_scales(model_name, scaler_means, scaler_scales):
    out_fnm = f"{model_name}_scales.txt"
    res = "#means"
    for mean_ in scaler_means:
        res += "\n" + str(mean_)
    res += "\n\n#scales"
    for scale_ in scaler_scales:
        res += "\n" + str(scale_)
    with open(f"../models/{out_fnm}", mode="w") as f:
        f.write(res)

# %%
#train/test split
x_train, x_test, y_train, y_test, = train_test_split(data, data_cond, test_size=0.2, shuffle=False)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)

#scale cond data
scaler = StandardScaler()
y_train = scaler.fit_transform(y_train)
y_test = scaler.transform(y_test)
print("cond max", y_train.max(), "min", y_train.min())

#save scales
save_scales("Proton", scaler.mean_, scaler.scale_)

# make tf datasets
dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(batch_size=128)
dataset_cond = tf.data.Dataset.from_tensor_slices(y_train).batch(batch_size=128)
dataset_with_cond = tf.data.Dataset.zip((dataset,dataset_cond)).shuffle(12800)

val_dataset = tf.data.Dataset.from_tensor_slices(x_test).batch(batch_size=128)
val_dataset_cond = tf.data.Dataset.from_tensor_slices(y_test).batch(batch_size=128)
val_dataset_with_cond = tf.data.Dataset.zip((val_dataset,val_dataset_cond)).shuffle(12800)
# Out:
# (81809, 56, 30) (20453, 56, 30) (81809, 11) (20453, 11)
# cond max 9.530952471918685 min -15.74070556621575

# %%
############################ Define Models ############################
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon


latent_dim = 10
cond_dim = 11
poz_dim = 6


############################ encoder ############################

input_img = Input(shape=[56,30,1],name='input_img')
input_cond = Input(shape=cond_dim,name='input_cond')
x = Conv2D(32, kernel_size=4, strides=2, padding='same')(input_img)
x = Conv2D(64, kernel_size=4, strides=2,padding='same')(x)
x = Conv2D(128, kernel_size=4, strides=2,padding='same')(x)
x = LeakyReLU(alpha=0.1)(x)
x = Flatten()(x)
x = layers.concatenate([input_cond,x])
x = layers.Dense(latent_dim*2, activation="relu")(x)
z_mean = layers.Dense(latent_dim, name="z_mean")(x)
z_log_var = layers.Dense(latent_dim, name="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])

encoder = keras.Model([input_img, input_cond], [z_mean, z_log_var, z], name="encoder")
encoder.summary()
############################ decoder ############################


x = Input(shape=(latent_dim,))
cond = Input(shape=(cond_dim,))
inputs = Concatenate(axis=1)([x, cond])

g = Dense(7*4*128)(inputs)
g = Reshape((7,4,128))(g)

g = UpSampling2D()(g)
g = Conv2D(128, kernel_size=4, padding='same')(g)
g = BatchNormalization()(g)
g = LeakyReLU(alpha=0)(g)

g = UpSampling2D()(g)
g = Conv2D(64, kernel_size=4, padding='same')(g)
g = BatchNormalization()(g)
g = LeakyReLU(alpha=0)(g)

g = UpSampling2D()(g)
g = Conv2D(32, kernel_size=4, padding='same')(g)
g = BatchNormalization()(g)
g = LeakyReLU(alpha=0)(g)

outputs = Conv2D(1, kernel_size=(1,3) ,activation='relu')(g)

generator = Model([x, cond], outputs, name='generator')
generator.summary()


# define losses
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)
d_acc_r = keras.metrics.BinaryAccuracy(name="d_acc_r", threshold=0.5)
d_acc_f = keras.metrics.BinaryAccuracy(name="d_acc_r", threshold=0.5)
g_acc = keras.metrics.BinaryAccuracy(name="g_acc_g", threshold=0.5)

# define optimizer
vae_optimizer = tf.keras.optimizers.RMSprop(1e-4)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_img (InputLayer)         [(None, 56, 30, 1)]  0           []
#
#  conv2d (Conv2D)                (None, 28, 15, 32)   544         ['input_img[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 14, 8, 64)    32832       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 4, 128)    131200      ['conv2d_1[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 7, 4, 128)    0           ['conv2d_2[0][0]']
#
#  input_cond (InputLayer)        [(None, 11)]         0           []
#
#  flatten (Flatten)              (None, 3584)         0           ['leaky_re_lu[0][0]']
#
#  concatenate (Concatenate)      (None, 3595)         0           ['input_cond[0][0]',
#                                                                   'flatten[0][0]']
#
#  dense (Dense)                  (None, 20)           71920       ['concatenate[0][0]']
#
#  z_mean (Dense)                 (None, 10)           210         ['dense[0][0]']
#
#  z_log_var (Dense)              (None, 10)           210         ['dense[0][0]']
#
#  sampling (Sampling)            (None, 10)           0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 236,916
# Trainable params: 236,916
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "generator"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10)]         0           []
#
#  input_2 (InputLayer)           [(None, 11)]         0           []
#
#  concatenate_1 (Concatenate)    (None, 21)           0           ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense_1 (Dense)                (None, 3584)         78848       ['concatenate_1[0][0]']
#
#  reshape (Reshape)              (None, 7, 4, 128)    0           ['dense_1[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 14, 8, 128)   0           ['reshape[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 14, 8, 128)   262272      ['up_sampling2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 14, 8, 128)  512         ['conv2d_3[0][0]']
#  alization)
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 14, 8, 128)   0           ['batch_normalization[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 28, 16, 128)  0          ['leaky_re_lu_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 16, 64)   131136      ['up_sampling2d_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 28, 16, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 28, 16, 64)   0           ['batch_normalization_1[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 56, 32, 64)  0           ['leaky_re_lu_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 32, 32)   32800       ['up_sampling2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 32, 32)  128         ['conv2d_5[0][0]']
#  rmalization)
#
#  leaky_re_lu_3 (LeakyReLU)      (None, 56, 32, 32)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 30, 1)    97          ['leaky_re_lu_3[0][0]']
#
# ==================================================================================================
# Total params: 506,049
# Trainable params: 505,601
# Non-trainable params: 448
# __________________________________________________________________________________________________

# %%
#trainin params

EPOCHS = 100
noise_dim = 10
num_examples_to_generate = 16

# Seed to reuse for generating samples for comparison during training
seed = tf.random.normal([num_examples_to_generate, noise_dim])
seed_cond = y_test[:num_examples_to_generate]


### function to calculate ws distance between orginal and generated channels
org=np.exp(x_test)-1
ch_org = org.reshape(-1,56,30)
ch_org = pd.DataFrame(sum_channels_parallel(ch_org)).values
del org

# %%
def calculate_ws_ch(n_calc):
    ws= [0,0,0,0,0]
    for j in range(n_calc):
        z = np.random.normal(0,1,(x_test.shape[0],10))
        z_c = y_test
        results = generator.predict([z,z_c])
        results = np.exp(results)-1
        try:
            ch_gen = np.array(results).reshape(-1,56,30)
            ch_gen = pd.DataFrame(sum_channels_parallel(ch_gen)).values
            for i in range(5):
                ws[i] = ws[i] + wasserstein_distance(ch_org[:,i], ch_gen[:,i])
            ws =np.array(ws)
        except ValueError as e:
            print(e)

    ws = ws/n_calc
    print("ws mean",f'{ws.sum()/5:.2f}', end=" ")
    for n, score in enumerate(ws):
        print("ch"+str(n+1),f'{score:.2f}',end=" ")
    return ws.sum()/5


####################### training ##############################
@tf.function
def train_step(batch,step):

    images, cond = batch
    step=step
    BATCH_SIZE = tf.shape(images)[0]

    #train vae
    with tf.GradientTape() as tape:
        z_mean, z_log_var, z = encoder([images, cond])
        reconstruction = generator([z, cond])
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                keras.losses.mean_squared_error(tf.reshape(images,(-1,56,30,1)), reconstruction), axis=(1, 2)
            )
        )
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = 0.7 * kl_loss + reconstruction_loss
    grads = tape.gradient(total_loss, generator.trainable_weights+encoder.trainable_weights)
    vae_optimizer.apply_gradients(zip(grads, generator.trainable_weights+encoder.trainable_weights))

    return total_loss, reconstruction_loss, kl_loss


history = []
ws_loss = []  # in each epoch
def train(dataset, epochs):
    tf_step =tf.Variable(0, dtype=float)
    step=0
    generate_and_save_images(generator,
                           epochs,
                           [seed, seed_cond])
    #print(calculate_ws_mae(3))
    for epoch in range(epochs):
        start = time.time()

        for batch in dataset:
            total_loss, reconstruction_loss, kl_loss =train_step(batch,tf_step)
            history.append([total_loss, reconstruction_loss, kl_loss])
            tf_step.assign_add(1)
            step = step+1

            if step%100==0:
                print("%d [Total loss: %.2f] [Recon_loss: %.2f] [KL loss: %.2f]"% (
                    step, total_loss, reconstruction_loss, kl_loss))

            # if step%1000==0:
            #     generate_and_save_images(generator,
            #                    epochs,
            #                    [seed, seed_cond])

        generate_and_save_images(generator,
                                 epoch + 1,
                                 [seed, seed_cond]
                                 )

        # # Save the model every epoch
        # encoder.save_weights("../models/enc_"+NAME + "_"+ str(epoch) +".h5")
        # generator.save_weights("../models/gen_"+NAME + "_"+ str(epoch) +".h5")
        # np.savez("../models/history_"+NAME+".npz",np.array(history))

        ws_epoch = calculate_ws_ch(min(epoch//5+1,5))

        print('Time for epoch {} is {} sec'.format(epoch + 1, time.time()-start))
        ws_loss.append(ws_epoch)
    return history



def generate_and_save_images(model, epoch, test_input):
    # Notice `training` is set to False.
    # This is so all layers run in inference mode (batchnorm).
    predictions = model(test_input, training=False)

    fig, axs = plt.subplots(2, 7, figsize=(15,4))
    fig.suptitle(f"Epoch: {epoch}")
    for i in range(0,14):
        if i <7:
            x = x_test[20+i].reshape(56,30)
        else:
            x = predictions[i-7].numpy().reshape(56,30)
        #x[x<=0]=x.max()*-0.1
        im = axs[i//7,i%7].imshow(x,interpolation='none', cmap='gnuplot')
        axs[i//7,i%7].axis('off')
        fig.colorbar(im, ax=axs[i//7,i%7])
    plt.show()
    plt.savefig('../images/image_at_epoch_{:04d}.png'.format(epoch))


# ### Train model
history=train(dataset_with_cond, EPOCHS)
# Out:
# 100 [Total loss: 10.60] [Recon_loss: 10.42] [KL loss: 0.26]
# 200 [Total loss: 6.06] [Recon_loss: 6.02] [KL loss: 0.06]
# 300 [Total loss: 6.61] [Recon_loss: 6.57] [KL loss: 0.06]
# 400 [Total loss: 7.52] [Recon_loss: 7.45] [KL loss: 0.10]
# 500 [Total loss: 5.09] [Recon_loss: 5.05] [KL loss: 0.05]
# 600 [Total loss: 8.94] [Recon_loss: 8.83] [KL loss: 0.16]
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.05 ch1 5.83 ch2 8.75 ch3 0.24 ch4 0.23 ch5 15.21 Time for epoch 1 is 32.93775033950806 sec
# 700 [Total loss: 6.75] [Recon_loss: 6.70] [KL loss: 0.08]
# 800 [Total loss: 8.04] [Recon_loss: 7.97] [KL loss: 0.10]
# 900 [Total loss: 6.35] [Recon_loss: 6.31] [KL loss: 0.06]
# 1000 [Total loss: 8.05] [Recon_loss: 7.97] [KL loss: 0.12]
# 1100 [Total loss: 8.53] [Recon_loss: 8.30] [KL loss: 0.32]
# 1200 [Total loss: 9.54] [Recon_loss: 9.43] [KL loss: 0.15]
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.28 ch1 5.78 ch2 9.40 ch3 0.23 ch4 0.22 ch5 15.76 Time for epoch 2 is 32.19599366188049 sec
# 1300 [Total loss: 8.05] [Recon_loss: 7.99] [KL loss: 0.09]
# 1400 [Total loss: 11.34] [Recon_loss: 11.00] [KL loss: 0.48]
# 1500 [Total loss: 10.83] [Recon_loss: 10.72] [KL loss: 0.16]
# 1600 [Total loss: 11.08] [Recon_loss: 11.00] [KL loss: 0.13]
# 1700 [Total loss: 8.22] [Recon_loss: 8.12] [KL loss: 0.15]
# 1800 [Total loss: 7.38] [Recon_loss: 7.33] [KL loss: 0.07]
# 1900 [Total loss: 7.82] [Recon_loss: 7.73] [KL loss: 0.12]
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.42 ch1 5.20 ch2 7.86 ch3 0.24 ch4 0.23 ch5 13.57 Time for epoch 3 is 32.349953413009644 sec
# 2000 [Total loss: 9.23] [Recon_loss: 9.14] [KL loss: 0.12]
# 2100 [Total loss: 6.98] [Recon_loss: 6.93] [KL loss: 0.08]
# 2200 [Total loss: 7.64] [Recon_loss: 7.57] [KL loss: 0.10]
# 2300 [Total loss: 6.84] [Recon_loss: 6.79] [KL loss: 0.06]
# 2400 [Total loss: 13.31] [Recon_loss: 13.09] [KL loss: 0.31]
# 2500 [Total loss: 8.44] [Recon_loss: 8.36] [KL loss: 0.12]
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.52 ch1 5.92 ch2 9.86 ch3 0.22 ch4 0.23 ch5 16.38 Time for epoch 4 is 32.94969582557678 sec
# 2600 [Total loss: 10.75] [Recon_loss: 10.38] [KL loss: 0.53]
# 2700 [Total loss: 9.46] [Recon_loss: 9.37] [KL loss: 0.12]
# 2800 [Total loss: 6.11] [Recon_loss: 6.06] [KL loss: 0.07]
# 2900 [Total loss: 8.84] [Recon_loss: 8.76] [KL loss: 0.11]
# 3000 [Total loss: 8.67] [Recon_loss: 8.60] [KL loss: 0.09]
# 3100 [Total loss: 9.68] [Recon_loss: 9.60] [KL loss: 0.11]
# 3200 [Total loss: 7.37] [Recon_loss: 7.32] [KL loss: 0.07]
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.13 ch1 5.74 ch2 9.03 ch3 0.24 ch4 0.24 ch5 15.40 Time for epoch 5 is 32.61613631248474 sec
# 3300 [Total loss: 6.89] [Recon_loss: 6.83] [KL loss: 0.09]
# 3400 [Total loss: 7.56] [Recon_loss: 7.51] [KL loss: 0.07]
# 3500 [Total loss: 6.82] [Recon_loss: 6.75] [KL loss: 0.09]
# 3600 [Total loss: 5.67] [Recon_loss: 5.64] [KL loss: 0.04]
# 3700 [Total loss: 13.09] [Recon_loss: 12.95] [KL loss: 0.20]
# 3800 [Total loss: 6.69] [Recon_loss: 6.66] [KL loss: 0.04]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.36 ch1 5.16 ch2 7.82 ch3 0.21 ch4 0.19 ch5 13.44 Time for epoch 6 is 36.90924644470215 sec
# 3900 [Total loss: 13.84] [Recon_loss: 13.42] [KL loss: 0.60]
# 4000 [Total loss: 9.10] [Recon_loss: 8.97] [KL loss: 0.18]
# 4100 [Total loss: 7.50] [Recon_loss: 7.45] [KL loss: 0.07]
# 4200 [Total loss: 6.74] [Recon_loss: 6.69] [KL loss: 0.06]
# 4300 [Total loss: 10.79] [Recon_loss: 10.70] [KL loss: 0.13]
# 4400 [Total loss: 7.40] [Recon_loss: 7.34] [KL loss: 0.09]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.10 ch1 5.05 ch2 7.18 ch3 0.22 ch4 0.23 ch5 12.82 Time for epoch 7 is 36.365936517715454 sec
# 4500 [Total loss: 7.54] [Recon_loss: 7.49] [KL loss: 0.08]
# 4600 [Total loss: 10.30] [Recon_loss: 10.18] [KL loss: 0.17]
# 4700 [Total loss: 6.09] [Recon_loss: 6.06] [KL loss: 0.05]
# 4800 [Total loss: 6.85] [Recon_loss: 6.80] [KL loss: 0.08]
# 4900 [Total loss: 7.75] [Recon_loss: 7.64] [KL loss: 0.16]
# 5000 [Total loss: 8.64] [Recon_loss: 8.58] [KL loss: 0.09]
# 5100 [Total loss: 7.13] [Recon_loss: 7.06] [KL loss: 0.10]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.67 ch1 5.96 ch2 10.16 ch3 0.24 ch4 0.23 ch5 16.76 Time for epoch 8 is 36.16752219200134 sec
# 5200 [Total loss: 8.53] [Recon_loss: 8.48] [KL loss: 0.07]
# 5300 [Total loss: 5.74] [Recon_loss: 5.69] [KL loss: 0.06]
# 5400 [Total loss: 10.47] [Recon_loss: 10.41] [KL loss: 0.09]
# 5500 [Total loss: 7.83] [Recon_loss: 7.75] [KL loss: 0.11]
# 5600 [Total loss: 6.55] [Recon_loss: 6.50] [KL loss: 0.08]
# 5700 [Total loss: 8.15] [Recon_loss: 8.08] [KL loss: 0.10]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.02 ch1 5.62 ch2 8.93 ch3 0.23 ch4 0.22 ch5 15.07 Time for epoch 9 is 36.52247714996338 sec
# 5800 [Total loss: 10.85] [Recon_loss: 10.66] [KL loss: 0.27]
# 5900 [Total loss: 9.70] [Recon_loss: 9.61] [KL loss: 0.14]
# 6000 [Total loss: 5.79] [Recon_loss: 5.75] [KL loss: 0.06]
# 6100 [Total loss: 9.09] [Recon_loss: 9.03] [KL loss: 0.08]
# 6200 [Total loss: 8.84] [Recon_loss: 8.78] [KL loss: 0.09]
# 6300 [Total loss: 7.39] [Recon_loss: 7.32] [KL loss: 0.10]
# 6400 [Total loss: 8.49] [Recon_loss: 8.38] [KL loss: 0.16]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.51 ch1 5.36 ch2 7.97 ch3 0.24 ch4 0.23 ch5 13.76 Time for epoch 10 is 36.05342721939087 sec
# 6500 [Total loss: 8.73] [Recon_loss: 8.66] [KL loss: 0.11]
# 6600 [Total loss: 8.15] [Recon_loss: 8.10] [KL loss: 0.08]
# 6700 [Total loss: 8.36] [Recon_loss: 8.30] [KL loss: 0.08]
# 6800 [Total loss: 7.77] [Recon_loss: 7.73] [KL loss: 0.06]
# 6900 [Total loss: 7.17] [Recon_loss: 7.11] [KL loss: 0.08]
# 7000 [Total loss: 4.73] [Recon_loss: 4.71] [KL loss: 0.03]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.31 ch1 5.48 ch2 7.32 ch3 0.24 ch4 0.23 ch5 13.30 Time for epoch 11 is 39.880953788757324 sec
# 7100 [Total loss: 8.62] [Recon_loss: 8.56] [KL loss: 0.10]
# 7200 [Total loss: 7.71] [Recon_loss: 7.64] [KL loss: 0.11]
# 7300 [Total loss: 6.95] [Recon_loss: 6.91] [KL loss: 0.06]
# 7400 [Total loss: 7.11] [Recon_loss: 7.07] [KL loss: 0.06]
# 7500 [Total loss: 7.66] [Recon_loss: 7.61] [KL loss: 0.07]
# 7600 [Total loss: 10.33] [Recon_loss: 10.12] [KL loss: 0.31]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.79 ch1 5.46 ch2 8.53 ch3 0.23 ch4 0.22 ch5 14.49 Time for epoch 12 is 39.54821801185608 sec
# 7700 [Total loss: 6.57] [Recon_loss: 6.53] [KL loss: 0.05]
# 7800 [Total loss: 8.04] [Recon_loss: 7.97] [KL loss: 0.11]
# 7900 [Total loss: 7.47] [Recon_loss: 7.41] [KL loss: 0.09]
# 8000 [Total loss: 6.42] [Recon_loss: 6.39] [KL loss: 0.05]
# 8100 [Total loss: 8.30] [Recon_loss: 8.11] [KL loss: 0.26]
# 8200 [Total loss: 7.06] [Recon_loss: 7.03] [KL loss: 0.04]
# 8300 [Total loss: 6.30] [Recon_loss: 6.27] [KL loss: 0.04]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.80 ch1 5.55 ch2 8.47 ch3 0.22 ch4 0.21 ch5 14.53 Time for epoch 13 is 39.883575439453125 sec
# 8400 [Total loss: 5.70] [Recon_loss: 5.67] [KL loss: 0.05]
# 8500 [Total loss: 5.71] [Recon_loss: 5.66] [KL loss: 0.08]
# 8600 [Total loss: 6.94] [Recon_loss: 6.92] [KL loss: 0.04]
# 8700 [Total loss: 9.21] [Recon_loss: 9.13] [KL loss: 0.12]
# 8800 [Total loss: 8.71] [Recon_loss: 8.65] [KL loss: 0.09]
# 8900 [Total loss: 8.59] [Recon_loss: 8.54] [KL loss: 0.08]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.01 ch1 5.87 ch2 8.67 ch3 0.22 ch4 0.23 ch5 15.09 Time for epoch 14 is 39.54061007499695 sec
# 9000 [Total loss: 9.48] [Recon_loss: 9.40] [KL loss: 0.12]
# 9100 [Total loss: 12.37] [Recon_loss: 12.29] [KL loss: 0.11]
# 9200 [Total loss: 8.87] [Recon_loss: 8.80] [KL loss: 0.09]
# 9300 [Total loss: 8.10] [Recon_loss: 8.02] [KL loss: 0.11]
# 9400 [Total loss: 10.36] [Recon_loss: 10.29] [KL loss: 0.10]
# 9500 [Total loss: 5.87] [Recon_loss: 5.84] [KL loss: 0.04]
# 9600 [Total loss: 9.69] [Recon_loss: 9.57] [KL loss: 0.18]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.51 ch1 5.13 ch2 8.18 ch3 0.22 ch4 0.21 ch5 13.79 Time for epoch 15 is 39.85760807991028 sec
# 9700 [Total loss: 4.84] [Recon_loss: 4.82] [KL loss: 0.03]
# 9800 [Total loss: 10.05] [Recon_loss: 9.98] [KL loss: 0.10]
# 9900 [Total loss: 8.75] [Recon_loss: 8.65] [KL loss: 0.15]
# 10000 [Total loss: 8.67] [Recon_loss: 8.61] [KL loss: 0.09]
# 10100 [Total loss: 7.32] [Recon_loss: 7.28] [KL loss: 0.07]
# 10200 [Total loss: 8.63] [Recon_loss: 8.57] [KL loss: 0.08]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.04 ch1 5.35 ch2 6.79 ch3 0.22 ch4 0.22 ch5 12.62 Time for epoch 16 is 43.004374980926514 sec
# 10300 [Total loss: 10.76] [Recon_loss: 10.65] [KL loss: 0.16]
# 10400 [Total loss: 10.62] [Recon_loss: 10.51] [KL loss: 0.15]
# 10500 [Total loss: 10.43] [Recon_loss: 10.33] [KL loss: 0.15]
# 10600 [Total loss: 9.77] [Recon_loss: 9.71] [KL loss: 0.08]
# 10700 [Total loss: 9.72] [Recon_loss: 9.65] [KL loss: 0.09]
# 10800 [Total loss: 8.57] [Recon_loss: 8.51] [KL loss: 0.08]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.95 ch1 5.54 ch2 8.87 ch3 0.24 ch4 0.21 ch5 14.87 Time for epoch 17 is 43.40461015701294 sec
# 10900 [Total loss: 7.28] [Recon_loss: 7.25] [KL loss: 0.04]
# 11000 [Total loss: 6.25] [Recon_loss: 6.21] [KL loss: 0.05]
# 11100 [Total loss: 9.48] [Recon_loss: 9.42] [KL loss: 0.08]
# 11200 [Total loss: 10.48] [Recon_loss: 10.28] [KL loss: 0.28]
# 11300 [Total loss: 5.96] [Recon_loss: 5.93] [KL loss: 0.04]
# 11400 [Total loss: 8.79] [Recon_loss: 8.72] [KL loss: 0.10]
# 11500 [Total loss: 4.83] [Recon_loss: 4.81] [KL loss: 0.03]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 6.09 ch1 5.70 ch2 9.07 ch3 0.21 ch4 0.19 ch5 15.27 Time for epoch 18 is 42.94988250732422 sec
# 11600 [Total loss: 6.10] [Recon_loss: 6.06] [KL loss: 0.07]
# 11700 [Total loss: 12.43] [Recon_loss: 12.29] [KL loss: 0.21]
# 11800 [Total loss: 5.13] [Recon_loss: 5.10] [KL loss: 0.05]
# 11900 [Total loss: 5.89] [Recon_loss: 5.87] [KL loss: 0.03]
# 12000 [Total loss: 9.53] [Recon_loss: 9.48] [KL loss: 0.07]
# 12100 [Total loss: 10.05] [Recon_loss: 9.97] [KL loss: 0.11]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 4.93 ch1 4.98 ch2 6.90 ch3 0.22 ch4 0.21 ch5 12.31 Time for epoch 19 is 43.33729958534241 sec
# 12200 [Total loss: 7.69] [Recon_loss: 7.61] [KL loss: 0.11]
# 12300 [Total loss: 11.98] [Recon_loss: 11.89] [KL loss: 0.13]
# 12400 [Total loss: 7.80] [Recon_loss: 7.74] [KL loss: 0.08]
# 12500 [Total loss: 7.35] [Recon_loss: 7.30] [KL loss: 0.07]
# 12600 [Total loss: 7.52] [Recon_loss: 7.47] [KL loss: 0.06]
# 12700 [Total loss: 5.69] [Recon_loss: 5.66] [KL loss: 0.04]
# 12800 [Total loss: 6.68] [Recon_loss: 6.61] [KL loss: 0.10]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.11 ch1 5.20 ch2 7.18 ch3 0.23 ch4 0.22 ch5 12.72 Time for epoch 20 is 42.90654635429382 sec
# 12900 [Total loss: 11.49] [Recon_loss: 11.19] [KL loss: 0.43]
# 13000 [Total loss: 8.83] [Recon_loss: 8.75] [KL loss: 0.11]
# 13100 [Total loss: 7.90] [Recon_loss: 7.83] [KL loss: 0.09]
# 13200 [Total loss: 6.37] [Recon_loss: 6.32] [KL loss: 0.06]
# 13300 [Total loss: 7.79] [Recon_loss: 7.73] [KL loss: 0.08]
# 13400 [Total loss: 6.57] [Recon_loss: 6.53] [KL loss: 0.05]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.50 ch1 5.31 ch2 8.03 ch3 0.22 ch4 0.21 ch5 13.73 Time for epoch 21 is 46.65430474281311 sec
# 13500 [Total loss: 7.05] [Recon_loss: 7.01] [KL loss: 0.06]
# 13600 [Total loss: 5.99] [Recon_loss: 5.95] [KL loss: 0.06]
# 13700 [Total loss: 6.51] [Recon_loss: 6.47] [KL loss: 0.06]
# 13800 [Total loss: 7.31] [Recon_loss: 7.28] [KL loss: 0.04]
# 13900 [Total loss: 7.87] [Recon_loss: 7.83] [KL loss: 0.07]
# 14000 [Total loss: 9.20] [Recon_loss: 9.15] [KL loss: 0.08]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.06 ch1 5.27 ch2 6.93 ch3 0.23 ch4 0.22 ch5 12.67 Time for epoch 22 is 44.871055126190186 sec
# 14100 [Total loss: 10.48] [Recon_loss: 10.42] [KL loss: 0.08]
# 14200 [Total loss: 7.18] [Recon_loss: 7.11] [KL loss: 0.10]
# 14300 [Total loss: 9.48] [Recon_loss: 9.38] [KL loss: 0.15]
# 14400 [Total loss: 4.63] [Recon_loss: 4.61] [KL loss: 0.04]
# 14500 [Total loss: 8.36] [Recon_loss: 8.30] [KL loss: 0.09]
# 14600 [Total loss: 9.44] [Recon_loss: 9.36] [KL loss: 0.11]
# 14700 [Total loss: 9.65] [Recon_loss: 9.57] [KL loss: 0.10]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.76 ch1 5.40 ch2 8.59 ch3 0.20 ch4 0.20 ch5 14.41 Time for epoch 23 is 44.674861669540405 sec
# 14800 [Total loss: 10.88] [Recon_loss: 10.81] [KL loss: 0.10]
# 14900 [Total loss: 6.59] [Recon_loss: 6.56] [KL loss: 0.04]
# 15000 [Total loss: 7.69] [Recon_loss: 7.65] [KL loss: 0.06]
# 15100 [Total loss: 7.13] [Recon_loss: 7.06] [KL loss: 0.09]
# 15200 [Total loss: 9.80] [Recon_loss: 9.72] [KL loss: 0.13]
# 15300 [Total loss: 5.86] [Recon_loss: 5.83] [KL loss: 0.05]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.49 ch1 5.47 ch2 7.86 ch3 0.23 ch4 0.22 ch5 13.67 Time for epoch 24 is 44.39153861999512 sec
# 15400 [Total loss: 7.18] [Recon_loss: 7.09] [KL loss: 0.14]
# 15500 [Total loss: 6.80] [Recon_loss: 6.77] [KL loss: 0.05]
# 15600 [Total loss: 5.74] [Recon_loss: 5.70] [KL loss: 0.06]
# 15700 [Total loss: 9.99] [Recon_loss: 9.93] [KL loss: 0.09]
# 15800 [Total loss: 6.26] [Recon_loss: 6.22] [KL loss: 0.05]
# 15900 [Total loss: 6.60] [Recon_loss: 6.56] [KL loss: 0.06]
# 16000 [Total loss: 5.84] [Recon_loss: 5.81] [KL loss: 0.04]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 4.95 ch1 5.06 ch2 6.90 ch3 0.21 ch4 0.19 ch5 12.40 Time for epoch 25 is 44.77845478057861 sec
# 16100 [Total loss: 9.07] [Recon_loss: 9.02] [KL loss: 0.07]
# 16200 [Total loss: 6.43] [Recon_loss: 6.40] [KL loss: 0.04]
# 16300 [Total loss: 5.53] [Recon_loss: 5.51] [KL loss: 0.03]
# 16400 [Total loss: 8.37] [Recon_loss: 8.34] [KL loss: 0.05]
# 16500 [Total loss: 7.06] [Recon_loss: 7.02] [KL loss: 0.05]
# 16600 [Total loss: 5.66] [Recon_loss: 5.63] [KL loss: 0.05]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.35 ch1 5.45 ch2 7.53 ch3 0.22 ch4 0.22 ch5 13.32 Time for epoch 26 is 44.400856256484985 sec
# 16700 [Total loss: 7.45] [Recon_loss: 7.42] [KL loss: 0.04]
# 16800 [Total loss: 7.08] [Recon_loss: 7.04] [KL loss: 0.05]
# 16900 [Total loss: 8.24] [Recon_loss: 8.19] [KL loss: 0.07]
# 17000 [Total loss: 9.20] [Recon_loss: 9.15] [KL loss: 0.07]
# 17100 [Total loss: 9.15] [Recon_loss: 8.94] [KL loss: 0.31]
# 17200 [Total loss: 9.55] [Recon_loss: 9.45] [KL loss: 0.14]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 4.58 ch1 4.98 ch2 6.04 ch3 0.22 ch4 0.22 ch5 11.42 Time for epoch 27 is 44.23025345802307 sec
# 17300 [Total loss: 7.80] [Recon_loss: 7.75] [KL loss: 0.07]
# 17400 [Total loss: 6.29] [Recon_loss: 6.24] [KL loss: 0.07]
# 17500 [Total loss: 7.14] [Recon_loss: 7.10] [KL loss: 0.05]
# 17600 [Total loss: 7.46] [Recon_loss: 7.41] [KL loss: 0.08]
# 17700 [Total loss: 6.44] [Recon_loss: 6.41] [KL loss: 0.05]
# 17800 [Total loss: 9.66] [Recon_loss: 9.57] [KL loss: 0.12]
# 17900 [Total loss: 6.36] [Recon_loss: 6.27] [KL loss: 0.12]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 4.97 ch1 5.17 ch2 6.84 ch3 0.22 ch4 0.22 ch5 12.41 Time for epoch 28 is 44.5096275806427 sec
# 18000 [Total loss: 5.84] [Recon_loss: 5.81] [KL loss: 0.04]
# 18100 [Total loss: 7.36] [Recon_loss: 7.33] [KL loss: 0.04]
# 18200 [Total loss: 9.27] [Recon_loss: 9.21] [KL loss: 0.08]
# 18300 [Total loss: 7.84] [Recon_loss: 7.79] [KL loss: 0.06]
# 18400 [Total loss: 6.13] [Recon_loss: 6.08] [KL loss: 0.07]
# 18500 [Total loss: 12.18] [Recon_loss: 12.12] [KL loss: 0.09]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.22 ch1 5.35 ch2 7.32 ch3 0.19 ch4 0.20 ch5 13.05 Time for epoch 29 is 44.23355722427368 sec
# 18600 [Total loss: 8.36] [Recon_loss: 8.32] [KL loss: 0.06]
# 18700 [Total loss: 5.10] [Recon_loss: 5.07] [KL loss: 0.04]
# 18800 [Total loss: 8.21] [Recon_loss: 8.15] [KL loss: 0.08]
# 18900 [Total loss: 5.34] [Recon_loss: 5.32] [KL loss: 0.03]
# 19000 [Total loss: 6.33] [Recon_loss: 6.31] [KL loss: 0.04]
# 19100 [Total loss: 9.72] [Recon_loss: 9.67] [KL loss: 0.06]
# 19200 [Total loss: 5.42] [Recon_loss: 5.39] [KL loss: 0.04]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 4.94 ch1 4.91 ch2 6.97 ch3 0.22 ch4 0.22 ch5 12.37 Time for epoch 30 is 44.77542591094971 sec
# 19300 [Total loss: 6.90] [Recon_loss: 6.84] [KL loss: 0.08]
# 19400 [Total loss: 9.42] [Recon_loss: 9.36] [KL loss: 0.09]
# 19500 [Total loss: 9.91] [Recon_loss: 9.85] [KL loss: 0.09]
# 19600 [Total loss: 10.17] [Recon_loss: 10.09] [KL loss: 0.10]
# 19700 [Total loss: 5.66] [Recon_loss: 5.62] [KL loss: 0.05]
# 19800 [Total loss: 7.05] [Recon_loss: 7.02] [KL loss: 0.05]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.69 ch1 5.44 ch2 8.34 ch3 0.22 ch4 0.21 ch5 14.24 Time for epoch 31 is 44.48664307594299 sec
# 19900 [Total loss: 8.07] [Recon_loss: 8.01] [KL loss: 0.09]
# 20000 [Total loss: 6.61] [Recon_loss: 6.56] [KL loss: 0.08]
# 20100 [Total loss: 8.33] [Recon_loss: 8.27] [KL loss: 0.08]
# 20200 [Total loss: 6.29] [Recon_loss: 6.26] [KL loss: 0.04]
# 20300 [Total loss: 7.38] [Recon_loss: 7.29] [KL loss: 0.14]
# 20400 [Total loss: 6.70] [Recon_loss: 6.68] [KL loss: 0.03]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.39 ch1 5.23 ch2 7.86 ch3 0.22 ch4 0.22 ch5 13.43 Time for epoch 32 is 45.216517210006714 sec
# 20500 [Total loss: 6.53] [Recon_loss: 6.49] [KL loss: 0.05]
# 20600 [Total loss: 7.21] [Recon_loss: 7.13] [KL loss: 0.12]
# 20700 [Total loss: 7.18] [Recon_loss: 7.13] [KL loss: 0.08]
# 20800 [Total loss: 7.25] [Recon_loss: 7.19] [KL loss: 0.09]
# 20900 [Total loss: 7.51] [Recon_loss: 7.47] [KL loss: 0.05]
# 21000 [Total loss: 5.61] [Recon_loss: 5.59] [KL loss: 0.03]
# 21100 [Total loss: 9.59] [Recon_loss: 9.52] [KL loss: 0.10]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.09 ch1 5.25 ch2 7.04 ch3 0.23 ch4 0.22 ch5 12.69 Time for epoch 33 is 45.373011112213135 sec
# 21200 [Total loss: 11.03] [Recon_loss: 10.96] [KL loss: 0.10]
# 21300 [Total loss: 12.54] [Recon_loss: 12.43] [KL loss: 0.15]
# 21400 [Total loss: 6.28] [Recon_loss: 6.25] [KL loss: 0.05]
# 21500 [Total loss: 9.62] [Recon_loss: 9.54] [KL loss: 0.10]
# 21600 [Total loss: 6.87] [Recon_loss: 6.83] [KL loss: 0.06]
# 21700 [Total loss: 8.04] [Recon_loss: 7.99] [KL loss: 0.07]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.38 ch1 5.42 ch2 7.64 ch3 0.22 ch4 0.20 ch5 13.41 Time for epoch 34 is 46.315489292144775 sec
# 21800 [Total loss: 7.57] [Recon_loss: 7.54] [KL loss: 0.04]
# 21900 [Total loss: 6.37] [Recon_loss: 6.33] [KL loss: 0.06]
# 22000 [Total loss: 8.33] [Recon_loss: 8.30] [KL loss: 0.05]
# 22100 [Total loss: 5.50] [Recon_loss: 5.45] [KL loss: 0.07]
# 22200 [Total loss: 13.78] [Recon_loss: 13.40] [KL loss: 0.55]
# 22300 [Total loss: 8.87] [Recon_loss: 8.82] [KL loss: 0.07]
# 22400 [Total loss: 6.81] [Recon_loss: 6.77] [KL loss: 0.06]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 4.85 ch1 4.95 ch2 6.80 ch3 0.21 ch4 0.21 ch5 12.06 Time for epoch 35 is 46.49417972564697 sec
# 22500 [Total loss: 11.25] [Recon_loss: 10.94] [KL loss: 0.43]
# 22600 [Total loss: 4.90] [Recon_loss: 4.88] [KL loss: 0.04]
# 22700 [Total loss: 13.24] [Recon_loss: 13.15] [KL loss: 0.13]
# 22800 [Total loss: 10.64] [Recon_loss: 10.53] [KL loss: 0.16]
# 22900 [Total loss: 9.87] [Recon_loss: 9.75] [KL loss: 0.18]
# 23000 [Total loss: 5.49] [Recon_loss: 5.47] [KL loss: 0.03]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 5.73 ch1 5.66 ch2 8.20 ch3 0.24 ch4 0.23 ch5 14.34 Time for epoch 36 is 46.691694259643555 sec
# 23100 [Total loss: 8.65] [Recon_loss: 8.59] [KL loss: 0.09]
# 23200 [Total loss: 6.49] [Recon_loss: 6.43] [KL loss: 0.09]
# 23300 [Total loss: 8.00] [Recon_loss: 7.95] [KL loss: 0.07]
# 23400 [Total loss: 12.55] [Recon_loss: 12.46] [KL loss: 0.13]
# 23500 [Total loss: 7.29] [Recon_loss: 7.25] [KL loss: 0.06]
# 23600 [Total loss: 6.65] [Recon_loss: 6.62] [KL loss: 0.04]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.27 ch1 5.49 ch2 7.23 ch3 0.22 ch4 0.23 ch5 13.18 Time for epoch 37 is 46.47664713859558 sec
# 23700 [Total loss: 8.65] [Recon_loss: 8.59] [KL loss: 0.10]
# 23800 [Total loss: 9.61] [Recon_loss: 9.55] [KL loss: 0.09]
# 23900 [Total loss: 8.14] [Recon_loss: 8.09] [KL loss: 0.08]
# 24000 [Total loss: 6.82] [Recon_loss: 6.79] [KL loss: 0.05]
# 24100 [Total loss: 9.25] [Recon_loss: 9.16] [KL loss: 0.13]
# 24200 [Total loss: 7.85] [Recon_loss: 7.78] [KL loss: 0.10]
# 24300 [Total loss: 9.65] [Recon_loss: 9.60] [KL loss: 0.07]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 4.40 ch1 4.78 ch2 5.89 ch3 0.21 ch4 0.20 ch5 10.92 Time for epoch 38 is 44.85184574127197 sec
# 24400 [Total loss: 9.91] [Recon_loss: 9.85] [KL loss: 0.09]
# 24500 [Total loss: 8.67] [Recon_loss: 8.60] [KL loss: 0.10]
# 24600 [Total loss: 5.68] [Recon_loss: 5.65] [KL loss: 0.04]
# 24700 [Total loss: 6.02] [Recon_loss: 5.98] [KL loss: 0.07]
# 24800 [Total loss: 9.06] [Recon_loss: 9.01] [KL loss: 0.07]
# 24900 [Total loss: 10.01] [Recon_loss: 9.95] [KL loss: 0.09]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.24 ch1 5.31 ch2 7.32 ch3 0.21 ch4 0.22 ch5 13.13 Time for epoch 39 is 44.72687745094299 sec
# 25000 [Total loss: 6.11] [Recon_loss: 6.08] [KL loss: 0.04]
# 25100 [Total loss: 8.08] [Recon_loss: 8.03] [KL loss: 0.08]
# 25200 [Total loss: 7.45] [Recon_loss: 7.40] [KL loss: 0.07]
# 25300 [Total loss: 6.94] [Recon_loss: 6.89] [KL loss: 0.06]
# 25400 [Total loss: 6.87] [Recon_loss: 6.83] [KL loss: 0.05]
# 25500 [Total loss: 9.86] [Recon_loss: 9.81] [KL loss: 0.08]
# 25600 [Total loss: 6.58] [Recon_loss: 6.56] [KL loss: 0.03]
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 4.96 ch1 5.13 ch2 6.85 ch3 0.21 ch4 0.20 ch5 12.41 Time for epoch 40 is 44.43719220161438 sec
# 25700 [Total loss: 7.43] [Recon_loss: 7.37] [KL loss: 0.08]
# 25800 [Total loss: 5.74] [Recon_loss: 5.72] [KL loss: 0.02]
# 25900 [Total loss: 6.66] [Recon_loss: 6.62] [KL loss: 0.05]
# 26000 [Total loss: 6.68] [Recon_loss: 6.63] [KL loss: 0.06]
# 26100 [Total loss: 7.79] [Recon_loss: 7.76] [KL loss: 0.04]
# 26200 [Total loss: 9.15] [Recon_loss: 9.09] [KL loss: 0.08]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.60 ch1 5.31 ch2 8.28 ch3 0.22 ch4 0.21 ch5 14.01 Time for epoch 41 is 44.79074716567993 sec
# 26300 [Total loss: 7.72] [Recon_loss: 7.68] [KL loss: 0.06]
# 26400 [Total loss: 8.10] [Recon_loss: 8.06] [KL loss: 0.06]
# 26500 [Total loss: 5.18] [Recon_loss: 5.05] [KL loss: 0.18]
# 26600 [Total loss: 5.23] [Recon_loss: 5.21] [KL loss: 0.02]
# 26700 [Total loss: 6.86] [Recon_loss: 6.82] [KL loss: 0.06]
# 26800 [Total loss: 8.58] [Recon_loss: 8.49] [KL loss: 0.13]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 4ms/step
# 640/640 [==============================] - 2s 3ms/step
# ws mean 5.79 ch1 5.57 ch2 8.45 ch3 0.21 ch4 0.20 ch5 14.51 Time for epoch 42 is 44.894230365753174 sec
# 26900 [Total loss: 8.00] [Recon_loss: 7.95] [KL loss: 0.06]
# 27000 [Total loss: 10.06] [Recon_loss: 9.99] [KL loss: 0.10]
# 27100 [Total loss: 13.81] [Recon_loss: 13.73] [KL loss: 0.11]
# 27200 [Total loss: 10.69] [Recon_loss: 10.63] [KL loss: 0.08]
# 27300 [Total loss: 8.97] [Recon_loss: 8.90] [KL loss: 0.10]
# 27400 [Total loss: 9.40] [Recon_loss: 9.23] [KL loss: 0.24]
# 27500 [Total loss: 10.08] [Recon_loss: 9.99] [KL loss: 0.12]
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 3ms/step
# 640/640 [==============================] - 2s 4ms/step
# ws mean 4.45 ch1 4.93 ch2 5.84 ch3 0.21 ch4 0.21 ch5 11.07 Time for epoch 43 is 45.175129890441895 sec
# 27600 [Total loss: 7.79] [Recon_loss: 7.77] [KL loss: 0.02]
# 27700 [Total loss: 11.22] [Recon_loss: 11.16] [KL loss: 0.10]
# 27800 [Total loss: 10.79] [Recon_loss: 10.58] [KL loss: 0.30]

# %%
print('doone')
# Out:
# doone
